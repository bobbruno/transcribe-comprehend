# %% [markdown]
# # Audio Processing
#
# This notebook shows a basic sequence of processing steps required to process audio files through Amazon Transcribe and Amazon Comprehend, to generate the data required for Sentiment Analysis of Contact Center calls. The steps themselves can be executed from any platform, the notebook is just convenient for step-by-step execution and experimentation.

# %% [markdown]
# ## Initial setup
#
# The libraries use some packages that are not installed by default. Install them by running the next cell.

# %%
# !pip install -U implicits pandas
# Out:
# Collecting implicits
#   Downloading implicits-1.0.2-py3-none-any.whl (3.7 kB)
# Collecting pandas
#   Downloading pandas-1.1.2-cp36-cp36m-manylinux1_x86_64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 12.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas) (1.18.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas) (1.14.0)
# Installing collected packages: implicits, pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# Successfully installed implicits-1.0.2 pandas-1.1.2
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Moving the data to the processing location

# %% [markdown]
# The data is available on the data folder. First, check that the audio files are there.

# %%
# !ls ../data/recordings/16KHz
# Out:
# 01740405-e5bf-463f-bc76-1d80f6412fff.wav
# 0174043c-d3a1-478a-a0ea-539c7075fb54.wav
# 017404e1-995b-418c-beb4-9ead3f79a7b6.wav
# 01740574-5169-4491-834e-c0cd2cd6120a.wav
# 01740677-ab28-4b30-89ca-18cb17b7d56e.wav
# 0174067d-f3b5-47e9-a826-b8b25239e74c.wav
# 0174068b-59cc-475a-aec4-659cd3b2f107.wav
# 01740694-7812-42b3-901e-c1576493d840.wav
# 01740b64-94fd-4556-9cfa-2010b4187d5f.wav
# 01742a46-8cc5-40bc-870d-06a3efd9fead.wav
# 01742a48-9802-45f1-82aa-0be122bd76b9.wav
# 01742a4a-efc9-4826-a455-ac52d1c2ff16.wav
# 01742a51-965c-4acb-ad77-68e397d5ff1e.wav
# 01742a57-8b54-4ca8-8412-fc62379d83b5.wav
# 01742faa-dc9f-4e3f-af1d-88f9ae19c2dc.wav
# 01742fb1-0d44-4239-98d7-1b924fbe94ad.wav

# %% [markdown]
# The cell above should list 16 audio files. Now copy the audio files to the bucket we'll use during the exercise. This is needed because Amazon Transcribe expects its data source to be files on S3.

# %%
import sagemaker as sm

bucket = sm.Session().default_bucket()
audio_source_path = "audio/contact-center/16KHz"
print(f"Copying files to s3://{bucket}/{audio_source_path}")
# !aws s3 sync "/home/ec2-user/SageMaker/transcribe-comprehend/data/recordings/16KHz/" s3://{bucket}/{audio_source_path}
# Out:
# Copying files to s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz

# %% [markdown]
# Check if the files are in the right bucket and folders. The `get_recording_files` function will retrieve a list of all files in the specified bucket and path. There should be a list of only ".wav" files as a result. If this is your result, we are ready to start transcribing.

# %%
from transcribe_utils import Speech, TranscriptReport, download_transcripts, get_recording_files, move_transcripts, \
    report_transcript, \
    transcribe_recording, \
    wait_for_jobs

file_names = get_recording_files(bucket=bucket, path=audio_source_path)
print("\n".join(file_names))
# Out:
# 0174043c-d3a1-478a-a0ea-539c7075fb54.wav
# 017404e1-995b-418c-beb4-9ead3f79a7b6.wav
# 01740574-5169-4491-834e-c0cd2cd6120a.wav
# 01740677-ab28-4b30-89ca-18cb17b7d56e.wav
# 0174067d-f3b5-47e9-a826-b8b25239e74c.wav
# 0174068b-59cc-475a-aec4-659cd3b2f107.wav
# 01740694-7812-42b3-901e-c1576493d840.wav
# 01740b64-94fd-4556-9cfa-2010b4187d5f.wav
# 01742a46-8cc5-40bc-870d-06a3efd9fead.wav
# 01742a48-9802-45f1-82aa-0be122bd76b9.wav
# 01742a4a-efc9-4826-a455-ac52d1c2ff16.wav
# 01742a51-965c-4acb-ad77-68e397d5ff1e.wav
# 01742a57-8b54-4ca8-8412-fc62379d83b5.wav
# 01742faa-dc9f-4e3f-af1d-88f9ae19c2dc.wav
# 01742fb1-0d44-4239-98d7-1b924fbe94ad.wav

# %% [markdown]
# ## Executing the Transcription

# %%
import time
import boto3
transcribe = boto3.client('transcribe')
vocabulary_name = "dpv-cc"

# %% [markdown]
# ### Custom Vocabulary Creation

# %% [markdown]
# Before starting the transcriptions, create a custom vocabulary to improve transcription quality. The vocabulary file was copied from the S3 backup above. Here's its contents:

# %%
# !cat ../data/vocabularies/vocabulary\ v1.txt
# Out:
# Gruner-und-Jahr
# Gruner-und-Jahr-Kundenservice
# Geo
# Brigitte
# Abo
# P.M.
# Zeitschriften
# Heften
# IBAN
# BIC
# Auftragsnummer
# Botenzustellung
# Botenversand
# E-Paper
# Registrierungslink
# Schlehenweg
# Mustermannstraße
# Musterhausen
# Moorrege
# Elli-Muster
# Murmelmann
# Elise-Musterfrau
# Margitt

# %% [markdown]
# Execute the following two cells to send the vocabulary to Amazon Transcribe and wait for its creation.It should take less than 2 minutes.

# %%
with open("../data/vocabularies/vocabulary v1.txt", "r") as f:
    vocab_entries = f.readlines()
vocab_entries = [entry[:-1] if entry[-1] == '\n' else entry for entry in vocab_entries]

vocab_result = transcribe.create_vocabulary(VocabularyName=vocabulary_name, LanguageCode='de-DE', Phrases=vocab_entries)

# %%
while vocab_result['VocabularyState'] not in {"READY", "FAILED"}:
    time.sleep(30)
    vocab_result = transcribe.get_vocabulary(VocabularyName=vocabulary_name)
    print(f"Vocabulary {vocabulary_name} still {vocab_result['VocabularyState']}...")
    
print(f"Vocabulary {vocabulary_name} {vocab_result['VocabularyState']}.")
# Out:
# Vocabulary dpv-cc still PENDING...
# Vocabulary dpv-cc still PENDING...
# Vocabulary dpv-cc still READY...
# Vocabulary dpv-cc READY...

# %% [markdown]
# Vocabulary creation takes a few minutes, you can check the progress on the <a href="https://console.aws.amazon.com/transcribe/home?region=us-east-1#vocabulary" target="_blank">Amazon Transcribe Console</a>. Wait until creation is complete, then cotinue the execution.

# %% [markdown]
# ### Execute Transcription Jobs

# %% [markdown]
# The cell below will submit transcription jobs for all the files in the bucket and path defined above. If you want to monitor the jobs themselves, open the <a href="https://console.aws.amazon.com/transcribe/home?region=us-east-1#" target="_blank">Amazon Transcribe console</a> in a new tab **before executing it**.
#
# If it's the first execution, the tab should be empty. Go ahead and execute the next cell to submit the audio recordings for transcription (you will need to refresh the console tab to see the jobs).

# %%
ts = str(int(time.time()))  # Avoiding conflicts in case of ressubmission
base_job_name = f"dpv-cc{ts}"
transcribe_jobs = []
for i, recording in enumerate(file_names):
    transcribe_jobs.append(
        transcribe_recording(
            recording, 
            job_name=f"{base_job_name}-{i + 1:03d}",
            bucket=bucket,
            path=audio_source_path,
            VocabularyName=vocabulary_name
        )
    )
# Out:
# Starting job dpv-cc1600072118-001 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174043c-d3a1-478a-a0ea-539c7075fb54.wav
# Starting job dpv-cc1600072118-002 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/017404e1-995b-418c-beb4-9ead3f79a7b6.wav
# Starting job dpv-cc1600072118-003 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740574-5169-4491-834e-c0cd2cd6120a.wav
# Starting job dpv-cc1600072118-004 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740677-ab28-4b30-89ca-18cb17b7d56e.wav
# Starting job dpv-cc1600072118-005 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174067d-f3b5-47e9-a826-b8b25239e74c.wav
# Starting job dpv-cc1600072118-006 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174068b-59cc-475a-aec4-659cd3b2f107.wav
# Starting job dpv-cc1600072118-007 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740694-7812-42b3-901e-c1576493d840.wav
# Starting job dpv-cc1600072118-008 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740b64-94fd-4556-9cfa-2010b4187d5f.wav
# Starting job dpv-cc1600072118-009 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a46-8cc5-40bc-870d-06a3efd9fead.wav
# Starting job dpv-cc1600072118-010 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a48-9802-45f1-82aa-0be122bd76b9.wav
# Starting job dpv-cc1600072118-011 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a4a-efc9-4826-a455-ac52d1c2ff16.wav
# Starting job dpv-cc1600072118-012 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a51-965c-4acb-ad77-68e397d5ff1e.wav
# Starting job dpv-cc1600072118-013 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a57-8b54-4ca8-8412-fc62379d83b5.wav
# Starting job dpv-cc1600072118-014 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742faa-dc9f-4e3f-af1d-88f9ae19c2dc.wav
# Starting job dpv-cc1600072118-015 for s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742fb1-0d44-4239-98d7-1b924fbe94ad.wav

# %% [markdown]
# The next cell will wait for transcribe to finish all jobs and move the resulting transcripts to a proper bucket

# %%
from pprint import pprint

transcript_dest_path = "transcribe-output"
final_job_results = wait_for_jobs(transcribe_jobs)
move_transcripts(jobs=final_job_results, dest_bucket=bucket, dest_path=transcript_dest_path)
pprint(final_job_results)
# Out:
# Waiting
# At least one in progress, wait more
# At least one in progress, wait more
# At least one in progress, wait more
# At least one in progress, wait more
# At least one in progress, wait more
# At least one in progress, wait more
# At least one in progress, wait more
# Job dpv-cc1600072118-001 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174043c-d3a1-478a-a0ea-539c7075fb54.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-001.json
#
# Job dpv-cc1600072118-002 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/017404e1-995b-418c-beb4-9ead3f79a7b6.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-002.json
#
# Job dpv-cc1600072118-003 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740574-5169-4491-834e-c0cd2cd6120a.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-003.json
#
# Job dpv-cc1600072118-004 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740677-ab28-4b30-89ca-18cb17b7d56e.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-004.json
#
# Job dpv-cc1600072118-005 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174067d-f3b5-47e9-a826-b8b25239e74c.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-005.json
#
# Job dpv-cc1600072118-006 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174068b-59cc-475a-aec4-659cd3b2f107.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-006.json
#
# Job dpv-cc1600072118-007 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740694-7812-42b3-901e-c1576493d840.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-007.json
#
# Job dpv-cc1600072118-008 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740b64-94fd-4556-9cfa-2010b4187d5f.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-008.json
#
# Job dpv-cc1600072118-009 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a46-8cc5-40bc-870d-06a3efd9fead.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-009.json
#
# Job dpv-cc1600072118-010 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a48-9802-45f1-82aa-0be122bd76b9.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-010.json
#
# Job dpv-cc1600072118-011 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a4a-efc9-4826-a455-ac52d1c2ff16.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-011.json
#
# Job dpv-cc1600072118-012 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a51-965c-4acb-ad77-68e397d5ff1e.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-012.json
#
# Job dpv-cc1600072118-013 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a57-8b54-4ca8-8412-fc62379d83b5.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-013.json
#
# Job dpv-cc1600072118-014 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742faa-dc9f-4e3f-af1d-88f9ae19c2dc.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-014.json
#
# Job dpv-cc1600072118-015 finished with status COMPLETED
# 	Media: s3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742fb1-0d44-4239-98d7-1b924fbe94ad.wav
# 	Transcript: https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-015.json
#
# {'dpv-cc1600072118-001': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '647',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:29:47 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '6edcecf2-1be3-4d0e-a5e3-93622bca3288'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '6edcecf2-1be3-4d0e-a5e3-93622bca3288',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 43, 9000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 38, 794000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174043c-d3a1-478a-a0ea-539c7075fb54.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 38, 820000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-001.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-001',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-002': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '647',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:29:58 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'a1dca779-ced6-481a-b594-0ed75e227958'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'a1dca779-ced6-481a-b594-0ed75e227958',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 52, 803000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 2000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/017404e1-995b-418c-beb4-9ead3f79a7b6.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 30000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-002.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-002',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-003': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '647',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '7ebd62b4-0310-4aad-aba1-5666d060e6a4'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '7ebd62b4-0310-4aad-aba1-5666d060e6a4',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 59, 126000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 225000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740574-5169-4491-834e-c0cd2cd6120a.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 250000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-003.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-003',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-004': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:07 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '813404d4-f8d9-40c1-998e-d0e8cbee882c'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '813404d4-f8d9-40c1-998e-d0e8cbee882c',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 30, 3, 801000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 443000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740677-ab28-4b30-89ca-18cb17b7d56e.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 492000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-004.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-004',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-005': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'd955d921-5bf0-4dcc-9cfc-f6419e231e5d'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'd955d921-5bf0-4dcc-9cfc-f6419e231e5d',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 30, 8, 117000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 809000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174067d-f3b5-47e9-a826-b8b25239e74c.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 39, 838000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-005.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-005',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-006': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:07 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'd9168fb0-f9f2-4604-9dc3-82d5a0056a1b'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'd9168fb0-f9f2-4604-9dc3-82d5a0056a1b',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 52, 308000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 22000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/0174068b-59cc-475a-aec4-659cd3b2f107.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 47000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-006.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-006',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-007': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '24a8f52c-def6-437b-bb0f-bf505e1c248d'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '24a8f52c-def6-437b-bb0f-bf505e1c248d',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 30, 5, 33000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 268000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740694-7812-42b3-901e-c1576493d840.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 297000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-007.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-007',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-008': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '84221947-f64f-4b44-9e56-1d694126ff06'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '84221947-f64f-4b44-9e56-1d694126ff06',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 30, 3, 599000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 467000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01740b64-94fd-4556-9cfa-2010b4187d5f.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 504000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-008.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-008',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-009': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'fd5fe0ad-869f-40db-95de-4e7319b03681'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'fd5fe0ad-869f-40db-95de-4e7319b03681',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 52, 48000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 741000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a46-8cc5-40bc-870d-06a3efd9fead.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 40, 797000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-009.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-009',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-010': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '9cc7bdfe-0fef-4f61-8d2b-3a27d7b394ea'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '9cc7bdfe-0fef-4f61-8d2b-3a27d7b394ea',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 34, 952000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 43000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a48-9802-45f1-82aa-0be122bd76b9.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 74000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-010.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-010',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-011': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'd94c837e-6125-4891-a072-6c1e6b771d15'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'd94c837e-6125-4891-a072-6c1e6b771d15',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 37, 551000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 282000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a4a-efc9-4826-a455-ac52d1c2ff16.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 307000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-011.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-011',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-012': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '6673a6ad-a638-4860-a855-9d274ac89c65'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '6673a6ad-a638-4860-a855-9d274ac89c65',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 30, 4, 472000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 491000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a51-965c-4acb-ad77-68e397d5ff1e.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 525000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-012.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-012',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-013': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:07 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '7921e881-371c-4db1-9078-160e9d7a9622'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '7921e881-371c-4db1-9078-160e9d7a9622',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 28, 344000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 739000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742a57-8b54-4ca8-8412-fc62379d83b5.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 766000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-013.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-013',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-014': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': 'fa5186ea-6bd9-4e53-9a68-f0139822ed2f'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': 'fa5186ea-6bd9-4e53-9a68-f0139822ed2f',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 36, 977000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 956000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742faa-dc9f-4e3f-af1d-88f9ae19c2dc.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 41, 985000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-014.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-014',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}}),
#  'dpv-cc1600072118-015': ('COMPLETED',
#                           {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                                                 'content-length': '648',
#                                                                 'content-type': 'application/x-amz-json-1.1',
#                                                                 'date': 'Mon, '
#                                                                         '14 '
#                                                                         'Sep '
#                                                                         '2020 '
#                                                                         '08:30:08 '
#                                                                         'GMT',
#                                                                 'x-amzn-requestid': '852d6c2c-ab5b-4a58-bcf5-2dbf21f35aba'},
#                                                 'HTTPStatusCode': 200,
#                                                 'RequestId': '852d6c2c-ab5b-4a58-bcf5-2dbf21f35aba',
#                                                 'RetryAttempts': 0},
#                            'TranscriptionJob': {'CompletionTime': datetime.datetime(2020, 9, 14, 8, 29, 30, 981000, tzinfo=tzlocal()),
#                                                 'CreationTime': datetime.datetime(2020, 9, 14, 8, 28, 42, 143000, tzinfo=tzlocal()),
#                                                 'LanguageCode': 'de-DE',
#                                                 'Media': {'MediaFileUri': 's3://sagemaker-us-east-1-160951647621/audio/contact-center/16KHz/01742fb1-0d44-4239-98d7-1b924fbe94ad.wav'},
#                                                 'MediaFormat': 'wav',
#                                                 'MediaSampleRateHertz': 16000,
#                                                 'Settings': {'ChannelIdentification': True,
#                                                              'MaxAlternatives': 2,
#                                                              'ShowAlternatives': True,
#                                                              'VocabularyName': 'dpv-cc'},
#                                                 'StartTime': datetime.datetime(2020, 9, 14, 8, 28, 42, 176000, tzinfo=tzlocal()),
#                                                 'Transcript': {'TranscriptFileUri': 'https://s3.us-east-1.amazonaws.com/sagemaker-us-east-1-160951647621/dpv-cc1600072118-015.json'},
#                                                 'TranscriptionJobName': 'dpv-cc1600072118-015',
#                                                 'TranscriptionJobStatus': 'COMPLETED'}})}

# %% [markdown]
# Download the transcriptions to the local storage to be able to see them.

# %%
local_transcripts_path = "../data/transcriptions/16KHz"
download_transcripts(bucket, transcript_dest_path, local_transcripts_path)
# Out:
# Downloading transcribe-output/dpv-cc1600045852-001.json into ../data/transcriptions/16KHz/dpv-cc1600045852-001.json
# Downloading transcribe-output/dpv-cc1600045852-002.json into ../data/transcriptions/16KHz/dpv-cc1600045852-002.json
# Downloading transcribe-output/dpv-cc1600045852-003.json into ../data/transcriptions/16KHz/dpv-cc1600045852-003.json
# Downloading transcribe-output/dpv-cc1600045852-004.json into ../data/transcriptions/16KHz/dpv-cc1600045852-004.json
# Downloading transcribe-output/dpv-cc1600045852-005.json into ../data/transcriptions/16KHz/dpv-cc1600045852-005.json
# Downloading transcribe-output/dpv-cc1600045852-006.json into ../data/transcriptions/16KHz/dpv-cc1600045852-006.json
# Downloading transcribe-output/dpv-cc1600045852-007.json into ../data/transcriptions/16KHz/dpv-cc1600045852-007.json
# Downloading transcribe-output/dpv-cc1600045852-008.json into ../data/transcriptions/16KHz/dpv-cc1600045852-008.json
# Downloading transcribe-output/dpv-cc1600045852-009.json into ../data/transcriptions/16KHz/dpv-cc1600045852-009.json
# Downloading transcribe-output/dpv-cc1600045852-010.json into ../data/transcriptions/16KHz/dpv-cc1600045852-010.json
# Downloading transcribe-output/dpv-cc1600045852-011.json into ../data/transcriptions/16KHz/dpv-cc1600045852-011.json
# Downloading transcribe-output/dpv-cc1600045852-012.json into ../data/transcriptions/16KHz/dpv-cc1600045852-012.json
# Downloading transcribe-output/dpv-cc1600045852-013.json into ../data/transcriptions/16KHz/dpv-cc1600045852-013.json
# Downloading transcribe-output/dpv-cc1600045852-014.json into ../data/transcriptions/16KHz/dpv-cc1600045852-014.json
# Downloading transcribe-output/dpv-cc1600045852-015.json into ../data/transcriptions/16KHz/dpv-cc1600045852-015.json

# %% [markdown]
# You can now navigate to the `data/transcriptionns/16KHz` folder and inspect the results of the transcriptions. You'll see that they contain:
# - A full text transcription
# - A detailed word by word transcription for each channel, with start time, end time and confidence.
# - A list of segments of speech per channel, also with start and end time and the list of each word identified.
#
# While very detailed, this format is difficult to read. In the next section we'll generate some basic reports and add sentiment information to the transcriptions.

# %% [markdown]
# ## Processing Transcription Outputs

# %% [markdown]
# The cell below will take each transcription and generate:
# - A text report with human-readable rendering of it
# - A sentiment analysis of the overall conversation
# - A detailed sentiment analysis of each segment

# %%
from glob import glob
from comprehend_utils import Sentiment, analyze_sentiment

def print_transcript_report(transcript_file, report, general_sentiment, sentiments, dest_processed_file=None):
    path = os.path.abspath(dest_processed_file if dest_processed_file else os.path.dirname(transcript_file))
    base_name, ext = os.path.splitext(os.path.basename(transcript_file))
    dest_file = os.path.join(path, f"{base_name}.txt")
    with open(dest_file, "w") as dest:
        dest.write(f"Job:\t\t{report.job}\nRecording:\t{report.recording}\nTranscript:\t{base_name}{ext}\n"
                   f"Speakers:\t{sorted(report.speakers)}\n")
        dest.write(f"Full Text:\n{report.full_text}\n")
        # noinspection PyProtectedMember
        dest.write(f"Sentiment: {general_sentiment.general}"
                   f" ({', '.join(f'{k[:3]}={v:0.3f}' for (k, v) in general_sentiment._asdict().items() if k != 'general')})\n")
        dest.write("\nDialogue:\n")
        for ((_, _, speaker, speech), sentiment) in zip(report.dialogue, sentiments):
            pred_sentiment: str = sentiment.general
            if sentiment.general == "POSITIVE":
                sentiment_strength = sentiment.positive
            elif sentiment.general == "NEGATIVE":
                sentiment_strength = sentiment.negative
            elif sentiment.general == "NEUTRAL":
                sentiment_strength = sentiment.neutral
            else:
                sentiment_strength = sentiment.mixed
            dest.write(f"{speaker} ({pred_sentiment[:3].lower()}: {sentiment_strength:0.3f}): {speech}\n")

comprehend = boto3.client('comprehend')
dialogues = []
for transcript in glob(f"{local_transcripts_path}/*.json"):
    transcript_report = report_transcript(transcript)
    general_sentiment = analyze_sentiment(transcript_report.full_text[:4500])
    sentiments = analyze_sentiment([speech.speech for speech in transcript_report.dialogue])
    print_transcript_report(transcript, transcript_report, general_sentiment, sentiments)
    dialogues.append((transcript, transcript_report.dialogue, sentiments))

# %% [markdown]
# Now you can see a text file for each transcription, which contains a readable report of the conversation. Open a few of them to see the results.
#
# In order to build better visualizations, create some files from the `dialogues` list. Execute the following cells to generate an HTML page, an Excel file and a Pandas dataframe, which we will use for visualization.

# %%
import pandas as pd

def dialogues_to_df(dialogues):
    """
    :param dialogues: List of transcribed dialogues with analysis. Each is (<transcript file name>, <dialogue>, <dialogue sentiment>)
    :return: None
    """
    data = {
        'transcript': [],
        'recording': [],
        'index': [],
        'speaker': [],
        'pred_sent': [],
        'speech': [],
        'positive': [],
        'negative': [],
        'mixed': [],
        'neutral': []
    }
    for (transcript, dialogue, sentiments) in dialogues:
        for i, (speech, sentiment) in enumerate(zip(dialogue, sentiments)):
            data['transcript'].append(os.path.basename(transcript))
            data['recording'].append(speech.recording)
            data['index'].append(i)
            data['speaker'].append(speech.speaker)
            data['pred_sent'].append(sentiment.general)
            data['speech'].append(speech.speech)
            data['positive'].append(sentiment.positive)
            data['negative'].append(sentiment.negative)
            data['mixed'].append(sentiment.mixed)
            data['neutral'].append(sentiment.neutral)
    df = pd.DataFrame(data)
    return df

def export_df(df, export_path, export_format="pickle", hdf_key=None) -> None:
    """
    Exports the dataframe in a variety of formats. Dataframe is expected to have columns `transcript` and `index`

    :param df: The dataframe to be exported
    :param export_path: Where to write the exported dataframe
    :param export_format: One of "html", "csv", "json", "parquet", "pickle", "hdf"
    :param hdf_key: if hdf format is used, key to store the df under in the HDF5 file
    """
    _, ext = os.path.splitext(export_path)
    use_ext = '.' + export_format if len(ext) == 0 else ''
    if export_format == "html":
        color_dict = {
            'POSITIVE': 'limegreen',
            'NEGATIVE': 'red',
            'NEUTRAL': 'lightgrey',
            'MIXED': 'yellow'
        }
        spk_dict = {
            'ch_0': '#F0F8FF',
            'spk_0': '#F0F8FF',
            'ch_1': '#FFF8DC',
            'spk_1': '#FFF8DC'
        }
        df.set_index(
            ['transcript', 'recording', 'speaker', 'index']
        ).to_html(export_path + use_ext, encoding='utf-8',
                  formatters={
                      'pred_sent': lambda sent: f'<span style="background-color:{color_dict[sent]}">{sent}</span>',
                      'speaker': lambda speaker: f'<span style="background-color:{spk_dict[speaker]}">{speaker}</span>'
                  }, escape=False)
    elif export_format == "csv":
        df.to_csv(export_path + use_ext)
    elif export_format == "json":
        df.to_json(export_path + use_ext)
    elif export_format == "parquet":
        df.to_parquet(export_path + use_ext)
    elif export_format == "pickle":
        df.to_pickle(export_path + use_ext)
    elif export_format == "excel":
        if len(use_ext) > 0:
            use_ext = '.xlsx'
        df.to_excel(export_path + use_ext, index=False)
    elif export_format == "hdf":
        assert hdf_key is not None, "Parameter hdf_key must be informed if export format is hdf."
        df.to_hdf(export_path + use_ext, hdf_key)
    else:
        raise ValueError(f"Unknown export format: {export_format}")

# %%
local_export_path = "../data/results/transcription"
df = dialogues_to_df(dialogues)
export_df(df, local_export_path, "html")
export_df(df, local_export_path, "pickle")
export_df(df, local_export_path, "excel")

# %% [markdown]
# With all processing done, you can open the `transcript_viz` notebook. You can also look at the code inside the `transcribe_utils` package and the `comprehend_utils` package to better understand all that was done above.
